# %%
from llm_tst_consistency.evaluator import load_template, load_cnn_daily_mail

dataset = load_cnn_daily_mail()
for record in dataset:
    print(record)
load_template("prompt_1.j2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from llm_tst_consistency.evaluator import load_template, load_cnn_daily_mail
# ----> 3 dataset = load_cnn_daily_mail()
#       4 for record in dataset:
#       5     print(record)
#
# File ~/Source/github.com/koosie0507/llm-tst-consistency/src/llm_tst_consistency/evaluator.py:17, in load_cnn_daily_mail()
#      16 def load_cnn_daily_mail():
# ---> 17     return load_dataset("abisee/cnn_dailymail", split="test")
#
# ...
